0.92388, 0, 0.19509, 0, -0.707107, 0, -0.980785, 0, -0.382683, 0, 0.55557, 0, 1, 0, 0.55557, 0, -0.382683, 0, -0.980785, 0, -0.707107, 0, 0.19509, 0, 0.92388, 0, 0.83147, 0, 6.12323e-16, 0, -0.83147, 0, -0.92388, 0, -0.19509, 0, 0.707107, 0, 0.980785, 0, 0.382683, 0, -0.55557, 0, -1, 0, -0.55557, 0, 0.382683, 0, 0.980785, 0, 0.707107, 0, -0.19509, 0, -0.92388, 0, -0.83147, 0,
# Out:
# (0.92388,
#  0,
#  0.19509,
#  0,
#  -0.707107,
#  0,
#  -0.980785,
#  0,
#  -0.382683,
#  0,
#  0.55557,
#  0,
#  1,
#  0,
#  0.55557,
#  0,
#  -0.382683,
#  0,
#  -0.980785,
#  0,
#  -0.707107,
#  0,
#  0.19509,
#  0,
#  0.92388,
#  0,
#  0.83147,
#  0,
#  6.12323e-16,
#  0,
#  -0.83147,
#  0,
#  -0.92388,
#  0,
#  -0.19509,
#  0,
#  0.707107,
#  0,
#  0.980785,
#  0,
#  0.382683,
#  0,
#  -0.55557,
#  0,
#  -1,
#  0,
#  -0.55557,
#  0,
#  0.382683,
#  0,
#  0.980785,
#  0,
#  0.707107,
#  0,
#  -0.19509,
#  0,
#  -0.92388,
#  0,
#  -0.83147,
#  0)

# %%
X_cpp
# Out:
# array([ 0.00000000e+00,  8.31469612e-01,  9.23879533e-01,  1.95090322e-01,
#        -7.07106781e-01, -9.80785280e-01, -3.82683432e-01,  5.55570233e-01,
#         1.00000000e+00,  5.55570233e-01, -3.82683432e-01, -9.80785280e-01,
#        -7.07106781e-01,  1.95090322e-01,  9.23879533e-01,  8.31469612e-01,
#         6.12323400e-16, -8.31469612e-01, -9.23879533e-01, -1.95090322e-01,
#         7.07106781e-01,  9.80785280e-01,  3.82683432e-01, -5.55570233e-01,
#        -1.00000000e+00, -5.55570233e-01,  3.82683432e-01,  9.80785280e-01,
#         7.07106781e-01, -1.95090322e-01, -9.23879533e-01, -8.31469612e-01,
#        -1.22464680e-15,  8.31469612e-01,  9.23879533e-01,  1.95090322e-01,
#        -7.07106781e-01, -9.80785280e-01, -3.82683432e-01,  5.55570233e-01,
#         1.00000000e+00,  5.55570233e-01, -3.82683432e-01, -9.80785280e-01,
#        -7.07106781e-01,  1.95090322e-01,  9.23879533e-01,  8.31469612e-01,
# ...

# %%
len(X_cpp)
# Out:
# 64

# %%
X = np.sin( t * (2*np.pi *freq) / transformLen)

# %%
Y = np.fft.fft(X)

# %%
np.real(Y)
# Out:
# array([-4.96198889e-16,  2.38075960e-15, -3.43271324e-16,  3.02938901e-15,
#         1.05724132e-14, -5.59876137e-15, -3.45189579e-15,  1.38312363e-14,
#         2.09588951e-15,  7.31232848e-15, -4.23097017e-14,  6.88937434e-15,
#         1.88257596e-15,  1.13323115e-14, -3.80996696e-15, -1.95971166e-15,
#         8.33007416e-15, -3.72337641e-16, -1.67553895e-15,  6.56420490e-15,
#         2.64784913e-15, -1.50814174e-14, -3.45189579e-15, -1.76283977e-14,
#         6.57065302e-15,  6.73920739e-15, -1.00940514e-15, -1.20338869e-15,
#         4.00660362e-15,  3.86546217e-15, -2.63282696e-15, -5.05910335e-16,
#         4.72184933e-15, -5.05910335e-16, -1.23144974e-15,  3.86546217e-15,
#         4.00660362e-15, -1.20338869e-15, -1.67553895e-15,  6.73920739e-15,
#         6.57065302e-15, -1.76283977e-14, -3.22985119e-15, -1.50814174e-14,
#         2.64784913e-15,  6.56420490e-15, -7.97184911e-16, -3.72337641e-16,
# ...

# %%
fig, axs = plt.subplots(2, 1, layout='constrained')
axs[0].plot(X)
axs[0].plot(X_cpp+ 0.1)
# axs[0].set_xlim(0, 2)
# axs[0].set_xlabel('Time (s)')
# axs[0].set_ylabel('s1 and s2')
# axs[0].grid(True)

# cxy, f = axs[1].cohere(s1, s2, 256, 1. / dt)
# axs[1].set_ylabel('Coherence')
axs[1].plot(np.abs(Y))
axs[1].plot(Y_cpp)


plt.show()

# %%
x_diff  = X - X_cpp
y_diff  = Y - Y_cpp

# %%
np.max(np.abs(X - X_cpp))
# Out:
# 4.57300863843102e-13

# %%
np.max(np.abs(np.abs(Y) - Y_cpp))
# Out:
# 1.3774624779666034e-15

# %%
y_diff
# Out:
# array([-1.19792989e-15+0.00000000e+00j, -5.98550040e-15+8.02036327e-15j,
#        -3.36671132e-15-1.99840144e-15j, -7.63098802e-18+2.15175513e-16j,
#        -2.76867941e-17+7.65407853e-16j, -1.12123214e-14+4.07288976e-16j,
#        -6.72220579e-15+8.88178420e-16j, -2.43563726e-16-2.60721817e-15j,
#        -5.49177049e-15+7.29244507e-15j, -1.05060715e-14+1.62488746e-14j,
#        -3.20000000e+01-3.20000000e+01j, -1.09861257e-14-1.64945029e-14j,
#        -7.73844043e-16-1.87416262e-15j, -1.71288530e-16+1.97767630e-15j,
#        -7.36647696e-15+2.39003164e-15j, -5.42434166e-15-2.85712564e-15j,
#        -1.41199584e-15+5.05151476e-15j, -7.56644641e-16+9.51670658e-17j,
#        -6.23835895e-15+5.10702591e-15j, -3.12947510e-15-7.13293332e-15j,
#        -1.50204509e-14+1.74687421e-14j, -3.06753174e-14+3.96495894e-15j,
#        -6.24615579e-15+0.00000000e+00j, -3.55454977e-14-3.20356770e-15j,
#        -1.21939470e-14-1.75765507e-14j, -2.66772614e-16+1.91488447e-15j,
# ...

# %%
X_cpp[3]
# Out:
# 0.195090322016

# %%
import matplotlib.pyplot as plt
import numpy as np

# Fixing random state for reproducibility
np.random.seed(19680801)

dt = 0.01
t = np.arange(0, 30, dt)
nse1 = np.random.randn(len(t))                 # white noise 1
nse2 = np.random.randn(len(t))                 # white noise 2

# Two signals with a coherent part at 10 Hz and a random part
s1 = np.sin(2 * np.pi * 10 * t) + nse1
s2 = np.sin(2 * np.pi * 10 * t) + nse2

fig, axs = plt.subplots(2, 1, layout='constrained')
axs[0].plot(t, s1, t, s2)
axs[0].set_xlim(0, 2)
axs[0].set_xlabel('Time (s)')
axs[0].set_ylabel('s1 and s2')
axs[0].grid(True)

cxy, f = axs[1].cohere(s1, s2, 256, 1. / dt)
axs[1].set_ylabel('Coherence')

plt.show()
